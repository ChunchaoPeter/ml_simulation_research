# %%
"""
Example Usage of ParticleFlowFilter Class

This script demonstrates how to use the ParticleFlowFilter class
to perform data assimilation on the Lorenz 96 model.
"""

import tensorflow as tf
import numpy as np
from pff import ParticleFlowFilter

from utils_pff_l96_rk4 import (
    L96_RK4, generate_L96_trajectory, generate_observations,
    generate_initial_ensemble, run_ensemble_no_DA,
    generate_Hx_si, H_linear_adjoint
)

# Set random seeds for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# # 1. EXPERIMENT SETUP

# %%
# Data assimilation settings
nt = 200               # Number of integration timesteps
warm_nt = 1000         # Warm up time for Lorenz model
np_particles = 30      # Number of particles

# L96 model parameters
dim = 40               # Dimension of Lorenz 96 model
F = 8.0                # Forcing parameter
dt = 0.01              # Time resolution

# Background error covariance
Q = 2 * tf.eye(dim, dtype=tf.float32)


# Observation setup
dim_interval = 4            # Observation density
obs_input = np.arange(dim_interval-1, dim, dim_interval)  # Python uses 0-indexing
ny_obs = len(obs_input)

nx = 40                     # Full state dimension
obs_interval = 4            # Observation frequency
obs_err = 0.3               # Observation error standard deviation
R = obs_err**2 * tf.eye(ny_obs, dtype=tf.float32)

# %% [markdown]
# # 2. GENERATE TRUTH AND OBSERVATIONS

# %%
# Generate truth trajectory
Xt = generate_L96_trajectory(
        dim, warm_nt, nt, dt, F, L96_RK4
)

# Generate observations
y_obs, obs_indices, dim_indices = generate_observations(
    Xt, nt, warm_nt, obs_interval, dim_interval, R, nx
)

# Generate initial ensemble
X = generate_initial_ensemble(
    Xt, warm_nt, dim, np_particles, nt, Q
)

# Run free forecast (no DA) for comparison
XnoDA = run_ensemble_no_DA(X, nt, dt, F, L96_RK4)
# Out:
# Integrating L96 model...
#   Step 200/1200
#   Step 400/1200
#   Step 600/1200
#   Step 800/1200
#   Step 1000/1200
# Initial ensemble generated with 30 particles
# Running ensemble without DA (free run)...
#   Timestep 50/200
#   Timestep 100/200
#   Timestep 150/200
# Free run complete!

# %% [markdown]
# # 3. INITIALIZE PARTICLE FLOW FILTER

# %%
alpha = 1.0 / np_particles

# PFF prior assumptions
inflation_fac = 1.25        # Inflation factor for prior covariance
r_influ = 4                 # Localization radius

# PFF iteration parameters
max_pseudo_step = 150       # Maximum number of iterations
eps_init = 5e-2             # Initial learning rate
stop_cri_percentage = 0.05  # Percentage-based stopping criterion
min_learning_rate = 1e-5    # Minimum learning rate
total_obs = nt // obs_interval  # Total number of observations

# %%
pff = ParticleFlowFilter(
    dim=dim,
    np_particles=np_particles,
    nt=nt,
    obs_interval=obs_interval,
    dim_interval=dim_interval,
    total_obs = total_obs,
    nx=nx,
    R=R,
    alpha=alpha,
    max_pseudo_step=max_pseudo_step,
    eps_init=eps_init,
    stop_cri_percentage=stop_cri_percentage,
    min_learning_rate=min_learning_rate,
    inflation_fac=inflation_fac,
    r_influ=r_influ,
    generate_Hx_si=generate_Hx_si,
    H_linear_adjoint=H_linear_adjoint
)

# %% [markdown]
# # 4.RUN DATA ASSIMILATION

# %%
DA_run = True

# %%
if DA_run:
    # Convert X to list format
    X_list = [X[:, :, i] for i in range(nt)]
    
    # Define model step function
    def model_step(X_current):
        """Wrapper for L96_RK4 model step."""
        return L96_RK4(X_current, dt, F=8)
    
    # Run PFF assimilation
    X_list_updated = pff.run(
        X_list=X_list,
        y_obs=y_obs,
        model_step=model_step,
        t_start=0,
        verbose=False
    )
    
    # Convert back to array format
    X_DA = tf.stack(X_list_updated, axis=2)
    
    print("\nData assimilation complete!")
    print(f"Output shape: {X_DA.shape}")
    
    # Save results
    # np.save('X_DA.npy', X_DA.numpy())
    
    # Get gradient history for diagnostics
    # grad_history = pff.get_gradient_history()
    # np.save('gradient_history.npy', grad_history)
# Out:
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
# ...
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#
# Data assimilation complete!
# Output shape: (40, 30, 200)

# %%
import matplotlib.pyplot as plt

# Calculate RMSE for both DA and no-DA runs
truth = Xt[:, warm_nt:warm_nt+nt]

# Ensemble mean
X_mean_DA = np.mean(X_DA, axis=1)
X_mean_noDA = np.mean(XnoDA, axis=1)

# RMSE over time
rmse_DA = np.sqrt(np.mean((X_mean_DA - truth)**2, axis=0))
rmse_noDA = np.sqrt(np.mean((X_mean_noDA - truth)**2, axis=0))

print(f"\nRMSE Statistics:")
print(f"  DA run - Mean RMSE: {np.mean(rmse_DA):.4f}")
print(f"  No-DA run - Mean RMSE: {np.mean(rmse_noDA):.4f}")
print(f"  Improvement: {(1 - np.mean(rmse_DA)/np.mean(rmse_noDA))*100:.2f}%")

# Plot RMSE comparison
plt.figure(figsize=(12, 4))
plt.plot(rmse_noDA, label='No DA', linewidth=2)
plt.plot(rmse_DA, label='With PFF DA', linewidth=2)
plt.xlabel('Time step')
plt.ylabel('RMSE')
plt.title('Root Mean Square Error: DA vs No-DA')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Plot ensemble spread
fig, axes = plt.subplots(2, 1, figsize=(12, 8))

# No-DA run
axes[0].imshow(X_mean_noDA, aspect='auto', cmap='RdBu_r', interpolation='nearest')
axes[0].set_title('Ensemble Mean - No DA')
axes[0].set_ylabel('State dimension')

# DA run
im = axes[1].imshow(X_mean_DA, aspect='auto', cmap='RdBu_r', interpolation='nearest')
axes[1].set_title('Ensemble Mean - With PFF DA')
axes[1].set_xlabel('Time step')
axes[1].set_ylabel('State dimension')

plt.colorbar(im, ax=axes, label='State value')
plt.tight_layout()
plt.show()

# Plot sample trajectory
sample_dim = 1
plt.figure(figsize=(12, 4))
plt.plot(truth[sample_dim, :], 'k-', linewidth=2, label='Truth', alpha=0.7)
plt.plot(X_mean_noDA[sample_dim, :], 'b--', linewidth=1.5, label='No DA')
plt.plot(X_mean_DA[sample_dim, :], 'r-', linewidth=1.5, label='With PFF DA')
plt.xlabel('Time step')
plt.ylabel('State value')
plt.title(f'Sample trajectory (dimension {sample_dim})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# RMSE Statistics:
#   DA run - Mean RMSE: 1.7062
#   No-DA run - Mean RMSE: 3.1678
#   Improvement: 46.14%
# /var/folders/fr/7vt2v5bs1f37tzqpnrrq0l880000gn/T/ipykernel_3184/2799045909.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # 5.ALTERNATIVE: MANUAL ASSIMILATION AT EACH TIME

# %%
# If you want more control, you can manually call assimilate() at each time:
if True:  # Set to True to run this example
    X_list_manual = [X[:, :, i] for i in range(nt)]
    t = 0
    
    while t < nt - 1:
        # Forecast
        X_next = L96_RK4(X_list_manual[t], dt, F)
        X_list_manual[t+1] = X_next
        
        # Check for observation
        if (t + 1) % obs_interval == 0:
            obs_time = (t + 1) // obs_interval -1
            
            # Perform assimilation
            X_list_manual[t+1], iterations = pff.assimilate(
                X_list=X_list_manual,
                y_obs=y_obs,
                t=t,
                obs_time=obs_time,
                verbose=True
            )
            
            print(f"Assimilation at t={t+1} completed in {iterations} iterations")
        
        t += 1
# Out:
#   Time t=4, Observation 1/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     Iteration s=10, norm=23.15%, eps=7.50e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=20, norm=13.26%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=30, norm=13.60%, eps=1.48e-02
#     Iteration s=40, norm=11.26%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=40, norm=11.85%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=40, norm=11.94%, eps=6.58e-03
#     Iteration s=50, norm=11.48%, eps=9.88e-03
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=50, norm=11.93%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=50, norm=11.97%, eps=5.78e-04
#     Iteration s=60, norm=12.19%, eps=8.67e-04
#     Iteration s=70, norm=12.60%, eps=1.30e-03
#     Iteration s=80, norm=13.40%, eps=2.93e-03
#     Iteration s=90, norm=14.71%, eps=4.39e-03
#     Iteration s=100, norm=14.84%, eps=6.58e-03
#     Iteration s=110, norm=11.74%, eps=9.88e-03
#     Iteration s=120, norm=11.45%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=120, norm=11.64%, eps=1.30e-03
#     Iteration s=130, norm=12.06%, eps=1.95e-03
#     Iteration s=140, norm=12.68%, eps=2.93e-03
#   PFF completed in 149 iterations
# Assimilation at t=4 completed in 149 iterations
#
#   Time t=8, Observation 2/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     Iteration s=10, norm=89.14%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=93.72%, eps=1.48e-02
#     Iteration s=30, norm=82.92%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=30, norm=85.42%, eps=6.58e-03
#     Iteration s=40, norm=95.34%, eps=9.88e-03
#     Iteration s=50, norm=71.59%, eps=1.48e-02
#     Iteration s=60, norm=64.80%, eps=2.22e-02
#     Iteration s=70, norm=64.38%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=80, norm=63.89%, eps=9.88e-03
#     Iteration s=90, norm=73.76%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=100, norm=76.69%, eps=6.58e-03
#     Iteration s=110, norm=63.78%, eps=9.88e-03
#     Iteration s=120, norm=57.05%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=120, norm=58.97%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=120, norm=59.69%, eps=4.39e-03
#     Iteration s=130, norm=66.34%, eps=6.58e-03
#     Iteration s=140, norm=63.45%, eps=9.88e-03
#   PFF completed in 149 iterations
# Assimilation at t=8 completed in 149 iterations
#
#   Time t=12, Observation 3/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=62.89%, eps=9.88e-03
#     Iteration s=20, norm=46.64%, eps=2.22e-02
#     Iteration s=30, norm=33.83%, eps=3.33e-02
#     Iteration s=40, norm=31.55%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=40, norm=32.08%, eps=6.58e-03
#     Iteration s=50, norm=30.20%, eps=9.88e-03
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=50, norm=31.21%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=50, norm=31.25%, eps=8.67e-04
#     Iteration s=60, norm=31.79%, eps=1.30e-03
#     Iteration s=70, norm=32.62%, eps=1.95e-03
#     Iteration s=80, norm=33.65%, eps=2.93e-03
#     Iteration s=90, norm=32.58%, eps=6.58e-03
#     Iteration s=100, norm=27.43%, eps=9.88e-03
#     Iteration s=110, norm=28.92%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=120, norm=27.00%, eps=6.58e-03
#     Iteration s=130, norm=16.94%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=140, norm=17.28%, eps=2.93e-03
#   PFF completed in 149 iterations
# Assimilation at t=12 completed in 149 iterations
#
#   Time t=16, Observation 4/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=50.85%, eps=1.48e-02
#     Iteration s=20, norm=41.04%, eps=3.33e-02
#     Iteration s=30, norm=27.68%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=30, norm=29.60%, eps=6.58e-03
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=30, norm=28.14%, eps=4.39e-03
#     Iteration s=40, norm=21.38%, eps=6.58e-03
#     Iteration s=50, norm=20.17%, eps=9.88e-03
#     Iteration s=60, norm=18.99%, eps=1.48e-02
#     Iteration s=70, norm=17.69%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=70, norm=18.72%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     Iteration s=70, norm=18.75%, eps=1.71e-04
#     Iteration s=80, norm=18.81%, eps=2.57e-04
#     Iteration s=90, norm=18.94%, eps=5.78e-04
#     Iteration s=100, norm=19.14%, eps=8.67e-04
#     Iteration s=110, norm=19.50%, eps=1.30e-03
#     Iteration s=120, norm=20.14%, eps=1.95e-03
#     Iteration s=130, norm=21.44%, eps=4.39e-03
#     Iteration s=140, norm=23.60%, eps=6.58e-03
#   PFF completed in 149 iterations
# Assimilation at t=16 completed in 149 iterations
#
#   Time t=20, Observation 5/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=10, norm=58.11%, eps=9.88e-03
#     Iteration s=20, norm=54.43%, eps=1.48e-02
#     Iteration s=30, norm=45.46%, eps=2.22e-02
#     Iteration s=40, norm=33.68%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=50, norm=27.71%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=50, norm=29.23%, eps=6.58e-03
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=50, norm=29.58%, eps=2.93e-03
#     Iteration s=60, norm=31.26%, eps=4.39e-03
#     Iteration s=70, norm=28.40%, eps=6.58e-03
#     Iteration s=80, norm=22.81%, eps=1.48e-02
#     Iteration s=90, norm=18.68%, eps=2.22e-02
#     Iteration s=100, norm=19.23%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=90, norm=19.23%, eps=5.78e-04
#     Iteration s=100, norm=19.36%, eps=8.67e-04
#     Iteration s=110, norm=19.60%, eps=1.30e-03
#     Iteration s=120, norm=20.02%, eps=1.95e-03
#     Iteration s=130, norm=20.86%, eps=4.39e-03
#     Iteration s=140, norm=22.37%, eps=6.58e-03
#   PFF completed in 149 iterations
# Assimilation at t=20 completed in 149 iterations
#
#   Time t=24, Observation 6/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=83.57%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=10, norm=57.65%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=41.34%, eps=1.48e-02
#     Iteration s=30, norm=34.47%, eps=2.22e-02
#     Iteration s=40, norm=23.19%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=40, norm=28.77%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=40, norm=21.02%, eps=4.39e-03
#     Iteration s=50, norm=19.77%, eps=6.58e-03
#     Iteration s=60, norm=18.36%, eps=1.48e-02
#     Iteration s=70, norm=16.50%, eps=2.22e-02
#     Iteration s=80, norm=14.98%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=80, norm=15.48%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=80, norm=15.61%, eps=4.39e-03
#     Iteration s=90, norm=17.04%, eps=6.58e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=90, norm=18.41%, eps=1.95e-03
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     Iteration s=80, norm=18.41%, eps=3.38e-05
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 76 iterations
# Assimilation at t=24 completed in 76 iterations
#
#   Time t=28, Observation 7/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=10, norm=57.48%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=10, norm=59.53%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=42.58%, eps=1.48e-02
#     Iteration s=30, norm=34.65%, eps=2.22e-02
#     Iteration s=40, norm=26.91%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=40, norm=30.04%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=40, norm=24.16%, eps=6.58e-03
#     Iteration s=50, norm=22.96%, eps=9.88e-03
#     Iteration s=60, norm=21.89%, eps=2.22e-02
#     Iteration s=70, norm=21.44%, eps=3.33e-02
#     Iteration s=80, norm=27.65%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=70, norm=27.65%, eps=8.67e-04
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     Iteration s=60, norm=27.65%, eps=1.50e-05
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 58 iterations
# Assimilation at t=28 completed in 58 iterations
#
#   Time t=32, Observation 8/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     Iteration s=10, norm=95.32%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=62.21%, eps=9.88e-03
#     Iteration s=20, norm=56.30%, eps=1.48e-02
#     Iteration s=30, norm=44.94%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=40, norm=36.75%, eps=1.48e-02
#     Iteration s=50, norm=36.94%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=50, norm=37.69%, eps=6.58e-03
#     Iteration s=60, norm=30.72%, eps=9.88e-03
#     Iteration s=70, norm=30.57%, eps=1.48e-02
#     Iteration s=80, norm=25.92%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=80, norm=26.53%, eps=1.48e-02
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=80, norm=27.10%, eps=4.39e-03
#     Iteration s=90, norm=27.52%, eps=6.58e-03
#     Iteration s=100, norm=22.10%, eps=9.88e-03
#     Iteration s=110, norm=21.19%, eps=2.22e-02
#     Iteration s=120, norm=23.11%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=120, norm=23.81%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     Iteration s=110, norm=23.81%, eps=5.07e-05
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 105 iterations
# Assimilation at t=32 completed in 105 iterations
#
#   Time t=36, Observation 9/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=75.73%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=20, norm=50.48%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=51.50%, eps=1.48e-02
#     Iteration s=30, norm=35.87%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=30, norm=36.86%, eps=2.93e-03
#     Iteration s=40, norm=30.97%, eps=4.39e-03
#     Iteration s=50, norm=29.29%, eps=6.58e-03
#     Iteration s=60, norm=27.22%, eps=9.88e-03
#     Iteration s=70, norm=24.76%, eps=2.22e-02
#     Iteration s=80, norm=21.02%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=80, norm=22.25%, eps=4.39e-03
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=80, norm=21.01%, eps=2.93e-03
#     Iteration s=90, norm=20.39%, eps=4.39e-03
#     Iteration s=100, norm=20.27%, eps=6.58e-03
#     Iteration s=110, norm=17.41%, eps=9.88e-03
#     Iteration s=120, norm=17.90%, eps=2.22e-02
#     Iteration s=130, norm=15.44%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=130, norm=17.14%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=130, norm=16.64%, eps=8.67e-04
#     Iteration s=140, norm=16.54%, eps=1.95e-03
#   PFF completed in 149 iterations
# Assimilation at t=36 completed in 149 iterations
#
#   Time t=40, Observation 10/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=10, norm=66.03%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=67.52%, eps=1.48e-02
#     Iteration s=20, norm=46.10%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=20, norm=51.72%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=20, norm=48.47%, eps=5.78e-04
#     Iteration s=30, norm=41.48%, eps=8.67e-04
#     Iteration s=40, norm=38.76%, eps=1.95e-03
#     Iteration s=50, norm=37.74%, eps=2.93e-03
#     Iteration s=60, norm=36.51%, eps=4.39e-03
#     Iteration s=70, norm=34.71%, eps=6.58e-03
#     Iteration s=80, norm=32.26%, eps=1.48e-02
#     Iteration s=90, norm=28.92%, eps=2.22e-02
#     Iteration s=100, norm=24.20%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=110, norm=21.40%, eps=1.48e-02
#     Iteration s=120, norm=19.53%, eps=2.22e-02
#     Iteration s=130, norm=17.35%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=130, norm=19.21%, eps=1.48e-02
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=130, norm=17.28%, eps=1.30e-03
#     Iteration s=140, norm=16.75%, eps=2.93e-03
#   PFF completed in 149 iterations
# Assimilation at t=40 completed in 149 iterations
#
#   Time t=44, Observation 11/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=10, norm=50.29%, eps=4.39e-03
#     Iteration s=20, norm=44.86%, eps=9.88e-03
#     Iteration s=30, norm=41.01%, eps=1.48e-02
#     Iteration s=40, norm=29.03%, eps=2.22e-02
#     Iteration s=50, norm=24.38%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=50, norm=23.30%, eps=1.48e-02
#     Iteration s=60, norm=24.10%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     Iteration s=50, norm=24.10%, eps=3.85e-04
#     Iteration s=60, norm=23.25%, eps=5.78e-04
#     Iteration s=70, norm=22.81%, eps=8.67e-04
#     Iteration s=80, norm=22.66%, eps=1.30e-03
#     Iteration s=90, norm=22.51%, eps=2.93e-03
#     Iteration s=100, norm=22.24%, eps=4.39e-03
#     Iteration s=110, norm=21.74%, eps=6.58e-03
#     Iteration s=120, norm=20.90%, eps=9.88e-03
#     Iteration s=130, norm=19.51%, eps=2.22e-02
#     Iteration s=140, norm=17.54%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#   PFF completed in 149 iterations
# Assimilation at t=44 completed in 149 iterations
#
#   Time t=48, Observation 12/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=10, norm=40.90%, eps=2.93e-03
#     Iteration s=20, norm=39.02%, eps=6.58e-03
#     Iteration s=30, norm=39.71%, eps=9.88e-03
#     Iteration s=40, norm=39.33%, eps=1.48e-02
#     Iteration s=50, norm=27.53%, eps=2.22e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=60, norm=24.35%, eps=6.58e-03
#     Iteration s=70, norm=23.06%, eps=1.48e-02
#     Iteration s=80, norm=20.65%, eps=2.22e-02
#     Iteration s=90, norm=18.09%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=90, norm=18.73%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=90, norm=17.30%, eps=6.58e-03
#     Iteration s=100, norm=16.69%, eps=9.88e-03
#     Iteration s=110, norm=16.31%, eps=1.48e-02
#     Iteration s=120, norm=15.40%, eps=2.22e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=120, norm=15.78%, eps=1.30e-03
#     Iteration s=130, norm=14.16%, eps=1.95e-03
#     Iteration s=140, norm=14.01%, eps=2.93e-03
#   PFF completed in 149 iterations
# Assimilation at t=48 completed in 149 iterations
#
#   Time t=52, Observation 13/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=10, norm=52.17%, eps=6.58e-03
#     Iteration s=20, norm=50.46%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=20, norm=53.41%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     Iteration s=10, norm=53.41%, eps=2.26e-05
#     Iteration s=20, norm=53.42%, eps=3.38e-05
#     Iteration s=30, norm=53.46%, eps=5.07e-05
#     Iteration s=40, norm=53.51%, eps=7.61e-05
#     Iteration s=50, norm=53.59%, eps=1.71e-04
#     Iteration s=60, norm=53.75%, eps=2.57e-04
#     Iteration s=70, norm=54.00%, eps=3.85e-04
#     Iteration s=80, norm=54.44%, eps=5.78e-04
#     Iteration s=90, norm=55.22%, eps=1.30e-03
#     Iteration s=100, norm=56.46%, eps=1.95e-03
#     Iteration s=110, norm=57.11%, eps=2.93e-03
#     Iteration s=120, norm=52.78%, eps=4.39e-03
#     Iteration s=130, norm=46.59%, eps=9.88e-03
#     Iteration s=140, norm=40.86%, eps=1.48e-02
#   PFF completed in 149 iterations
# Assimilation at t=52 completed in 149 iterations
#
#   Time t=56, Observation 14/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=72.79%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=10, norm=76.49%, eps=1.95e-03
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=10, norm=73.86%, eps=1.30e-03
#     Iteration s=20, norm=51.38%, eps=1.95e-03
#     Iteration s=30, norm=47.58%, eps=2.93e-03
#     Iteration s=40, norm=45.45%, eps=4.39e-03
#     Iteration s=50, norm=42.51%, eps=9.88e-03
#     Iteration s=60, norm=38.94%, eps=1.48e-02
#     Iteration s=70, norm=34.95%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=70, norm=38.99%, eps=8.67e-04
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     Iteration s=70, norm=38.59%, eps=5.07e-05
#     Iteration s=80, norm=37.84%, eps=7.61e-05
#     Iteration s=90, norm=36.77%, eps=1.14e-04
#     Iteration s=100, norm=35.34%, eps=1.71e-04
#     Iteration s=110, norm=33.69%, eps=3.85e-04
#     Iteration s=120, norm=32.28%, eps=5.78e-04
#     Iteration s=130, norm=31.57%, eps=8.67e-04
#     Iteration s=140, norm=31.34%, eps=1.30e-03
#   PFF completed in 149 iterations
# Assimilation at t=56 completed in 149 iterations
#
#   Time t=60, Observation 15/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=47.85%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=50.67%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=10, norm=45.87%, eps=6.58e-03
#     Iteration s=20, norm=44.77%, eps=9.88e-03
#     Iteration s=30, norm=44.22%, eps=1.48e-02
#     Iteration s=40, norm=42.29%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=50, norm=38.40%, eps=9.88e-03
#     Iteration s=60, norm=37.62%, eps=1.48e-02
#     Iteration s=70, norm=36.56%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=70, norm=43.23%, eps=8.67e-04
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     Iteration s=60, norm=43.23%, eps=1.50e-05
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 58 iterations
# Assimilation at t=60 completed in 58 iterations
#
#   Time t=64, Observation 16/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=39.44%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=37.91%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=34.82%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=30, norm=30.83%, eps=9.88e-03
#     Iteration s=40, norm=30.63%, eps=1.48e-02
#     Iteration s=50, norm=27.55%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=50, norm=31.98%, eps=4.39e-03
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     Iteration s=40, norm=31.98%, eps=7.61e-05
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 34 iterations
# Assimilation at t=64 completed in 34 iterations
#
#   Time t=68, Observation 17/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=61.38%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=10, norm=64.55%, eps=4.39e-03
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=10, norm=60.65%, eps=2.93e-03
#     Iteration s=20, norm=54.98%, eps=4.39e-03
#     Iteration s=30, norm=52.98%, eps=6.58e-03
#     Iteration s=40, norm=50.47%, eps=9.88e-03
#     Iteration s=50, norm=46.85%, eps=2.22e-02
#     Iteration s=60, norm=41.96%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=60, norm=46.28%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=60, norm=42.14%, eps=8.67e-04
#     Iteration s=70, norm=39.89%, eps=1.95e-03
#     Iteration s=80, norm=39.38%, eps=2.93e-03
#     Iteration s=90, norm=38.71%, eps=4.39e-03
#     Iteration s=100, norm=37.64%, eps=6.58e-03
#     Iteration s=110, norm=35.87%, eps=1.48e-02
#     Iteration s=120, norm=33.06%, eps=2.22e-02
#     Iteration s=130, norm=29.52%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=130, norm=30.81%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=130, norm=28.89%, eps=9.88e-03
#     Iteration s=140, norm=29.17%, eps=1.48e-02
#   PFF completed in 149 iterations
# Assimilation at t=68 completed in 149 iterations
#
#   Time t=72, Observation 18/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=10, norm=52.97%, eps=4.39e-03
#     Iteration s=20, norm=50.67%, eps=9.88e-03
#     Iteration s=30, norm=45.90%, eps=1.48e-02
#     Iteration s=40, norm=40.46%, eps=2.22e-02
#     Iteration s=50, norm=33.38%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=50, norm=40.11%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     Iteration s=50, norm=33.74%, eps=1.30e-03
#     Iteration s=60, norm=31.24%, eps=1.95e-03
#     Iteration s=70, norm=30.75%, eps=2.93e-03
#     Iteration s=80, norm=30.15%, eps=4.39e-03
#     Iteration s=90, norm=29.24%, eps=9.88e-03
#     Iteration s=100, norm=28.43%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=100, norm=29.69%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     Iteration s=100, norm=29.70%, eps=7.61e-05
#     Iteration s=110, norm=29.74%, eps=1.14e-04
#     Iteration s=120, norm=29.79%, eps=1.71e-04
#     Iteration s=130, norm=29.89%, eps=2.57e-04
#     Iteration s=140, norm=30.08%, eps=5.78e-04
#   PFF completed in 149 iterations
# Assimilation at t=72 completed in 149 iterations
#
#   Time t=76, Observation 19/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=10, norm=79.91%, eps=2.93e-03
#     Iteration s=20, norm=77.23%, eps=4.39e-03
#     Iteration s=30, norm=74.42%, eps=6.58e-03
#     Iteration s=40, norm=69.88%, eps=9.88e-03
#     Iteration s=50, norm=62.30%, eps=2.22e-02
#     Iteration s=60, norm=51.63%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=70, norm=44.44%, eps=1.48e-02
#     Iteration s=80, norm=41.34%, eps=2.22e-02
#     Iteration s=90, norm=33.09%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=90, norm=35.74%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=90, norm=31.09%, eps=4.39e-03
#     Iteration s=100, norm=29.51%, eps=6.58e-03
#     Iteration s=110, norm=27.97%, eps=9.88e-03
#     Iteration s=120, norm=26.04%, eps=2.22e-02
#     Iteration s=130, norm=22.66%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=130, norm=23.41%, eps=6.58e-03
#     Iteration s=140, norm=20.85%, eps=9.88e-03
#   PFF completed in 149 iterations
# Assimilation at t=76 completed in 149 iterations
#
#   Time t=80, Observation 20/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=64.98%, eps=2.22e-02
#     Iteration s=20, norm=56.02%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=51.15%, eps=1.48e-02
#     Iteration s=30, norm=44.68%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=30, norm=46.60%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=30, norm=44.21%, eps=1.95e-03
#     Iteration s=40, norm=38.98%, eps=2.93e-03
#     Iteration s=50, norm=38.03%, eps=4.39e-03
#     Iteration s=60, norm=36.62%, eps=6.58e-03
#     Iteration s=70, norm=34.74%, eps=1.48e-02
#     Iteration s=80, norm=31.93%, eps=2.22e-02
#     Iteration s=90, norm=30.35%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=90, norm=34.25%, eps=1.48e-02
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     Iteration s=80, norm=34.25%, eps=2.57e-04
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     Iteration s=80, norm=34.10%, eps=3.38e-05
#     Iteration s=90, norm=33.73%, eps=5.07e-05
#     Iteration s=100, norm=33.13%, eps=1.14e-04
#     Iteration s=110, norm=32.30%, eps=1.71e-04
#     Iteration s=120, norm=31.31%, eps=2.57e-04
#     Iteration s=130, norm=30.34%, eps=3.85e-04
#     Iteration s=140, norm=29.59%, eps=8.67e-04
#   PFF completed in 149 iterations
# Assimilation at t=80 completed in 149 iterations
#
#   Time t=84, Observation 21/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=10, norm=73.65%, eps=2.93e-03
#     Iteration s=20, norm=71.85%, eps=4.39e-03
#     Iteration s=30, norm=69.99%, eps=6.58e-03
#     Iteration s=40, norm=66.30%, eps=9.88e-03
#     Iteration s=50, norm=58.55%, eps=2.22e-02
#     Iteration s=60, norm=49.36%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
# ...
#
#   Time t=176, Observation 44/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=74.54%, eps=1.48e-02
#     Iteration s=20, norm=66.39%, eps=2.22e-02
#     Iteration s=30, norm=57.53%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=30, norm=59.22%, eps=1.48e-02
#     Iteration s=40, norm=49.41%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=40, norm=50.46%, eps=1.48e-02
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=40, norm=47.33%, eps=9.88e-03
#     Iteration s=50, norm=44.44%, eps=1.48e-02
#     Iteration s=60, norm=39.99%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=70, norm=33.38%, eps=6.58e-03
#     Iteration s=80, norm=32.10%, eps=9.88e-03
#     Iteration s=90, norm=30.78%, eps=2.22e-02
#     Iteration s=100, norm=26.46%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=100, norm=35.13%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     Iteration s=90, norm=35.13%, eps=1.71e-04
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 82 iterations
# Assimilation at t=176 completed in 82 iterations
#
#   Time t=180, Observation 45/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=57.60%, eps=1.48e-02
#     Iteration s=20, norm=47.67%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=20, norm=42.14%, eps=1.48e-02
#     Iteration s=30, norm=35.78%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=30, norm=41.29%, eps=4.39e-03
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     Iteration s=30, norm=39.25%, eps=2.57e-04
#     Iteration s=40, norm=35.58%, eps=5.78e-04
#     Iteration s=50, norm=32.80%, eps=8.67e-04
#     Iteration s=60, norm=31.75%, eps=1.30e-03
#     Iteration s=70, norm=31.27%, eps=1.95e-03
#     Iteration s=80, norm=30.55%, eps=4.39e-03
#     Iteration s=90, norm=29.48%, eps=6.58e-03
#     Iteration s=100, norm=28.43%, eps=9.88e-03
#     Iteration s=110, norm=26.20%, eps=1.48e-02
#     Iteration s=120, norm=21.55%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=120, norm=26.94%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     Iteration s=110, norm=26.94%, eps=5.07e-05
#     Iteration s=120, norm=26.25%, eps=7.61e-05
#     Iteration s=130, norm=25.20%, eps=1.14e-04
#     Iteration s=140, norm=23.70%, eps=1.71e-04
#   PFF completed in 149 iterations
# Assimilation at t=180 completed in 149 iterations
#
#   Time t=184, Observation 46/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=10, norm=53.59%, eps=2.93e-03
#     Iteration s=20, norm=48.84%, eps=4.39e-03
#     Iteration s=30, norm=45.61%, eps=6.58e-03
#     Iteration s=40, norm=42.24%, eps=9.88e-03
#     Iteration s=50, norm=37.70%, eps=2.22e-02
#     Iteration s=60, norm=32.05%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=60, norm=34.11%, eps=6.58e-03
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=60, norm=30.71%, eps=2.93e-03
#     Iteration s=70, norm=29.06%, eps=4.39e-03
#     Iteration s=80, norm=28.42%, eps=6.58e-03
#     Iteration s=90, norm=27.42%, eps=1.48e-02
#     Iteration s=100, norm=25.99%, eps=2.22e-02
#     Iteration s=110, norm=24.25%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=110, norm=28.55%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     Iteration s=100, norm=28.55%, eps=1.71e-04
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 92 iterations
# Assimilation at t=184 completed in 92 iterations
#
#   Time t=188, Observation 47/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=10, norm=45.60%, eps=2.93e-03
#     Iteration s=20, norm=41.70%, eps=4.39e-03
#     Iteration s=30, norm=39.67%, eps=6.58e-03
#     Iteration s=40, norm=39.02%, eps=9.88e-03
#     Iteration s=50, norm=39.64%, eps=2.22e-02
#     Iteration s=60, norm=28.96%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=60, norm=34.96%, eps=4.39e-03
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=60, norm=31.82%, eps=5.78e-04
#     Iteration s=70, norm=26.76%, eps=8.67e-04
#     Iteration s=80, norm=24.55%, eps=1.95e-03
#     Iteration s=90, norm=24.10%, eps=2.93e-03
#     Iteration s=100, norm=23.60%, eps=4.39e-03
#     Iteration s=110, norm=22.85%, eps=6.58e-03
#     Iteration s=120, norm=21.66%, eps=1.48e-02
#     Iteration s=130, norm=20.28%, eps=2.22e-02
#     Iteration s=140, norm=17.88%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=140, norm=18.52%, eps=1.48e-02
#   PFF completed in 149 iterations
# Assimilation at t=188 completed in 149 iterations
#
#   Time t=192, Observation 48/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=0, norm=100.00%, eps=9.88e-03
#     Iteration s=10, norm=67.10%, eps=1.48e-02
#     Iteration s=20, norm=55.62%, eps=2.22e-02
#     Iteration s=30, norm=59.37%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=20, norm=59.37%, eps=5.78e-04
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     Iteration s=20, norm=58.71%, eps=1.71e-04
#     Iteration s=30, norm=56.43%, eps=2.57e-04
#     Iteration s=40, norm=54.27%, eps=3.85e-04
#     Iteration s=50, norm=52.75%, eps=8.67e-04
#     Iteration s=60, norm=52.06%, eps=1.30e-03
#     Iteration s=70, norm=51.56%, eps=1.95e-03
#     Iteration s=80, norm=50.91%, eps=2.93e-03
#     Iteration s=90, norm=50.09%, eps=6.58e-03
#     Iteration s=100, norm=49.24%, eps=9.88e-03
#     Iteration s=110, norm=49.56%, eps=1.48e-02
#     Iteration s=120, norm=48.59%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=130, norm=42.02%, eps=4.39e-03
#     Iteration s=140, norm=40.51%, eps=6.58e-03
#   PFF completed in 149 iterations
# Assimilation at t=192 completed in 149 iterations
#
#   Time t=196, Observation 49/50
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=0, norm=100.00%, eps=9.88e-03
#     Iteration s=10, norm=75.94%, eps=1.48e-02
#     Iteration s=20, norm=61.60%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=30, norm=57.63%, eps=4.39e-03
#     Iteration s=40, norm=57.56%, eps=6.58e-03
#     Iteration s=50, norm=57.52%, eps=9.88e-03
#     Iteration s=60, norm=55.52%, eps=1.48e-02
#     Iteration s=70, norm=53.47%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=70, norm=54.80%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=70, norm=53.22%, eps=1.30e-03
#     Iteration s=80, norm=52.77%, eps=2.93e-03
#     Iteration s=90, norm=52.27%, eps=4.39e-03
#     Iteration s=100, norm=51.39%, eps=6.58e-03
#     Iteration s=110, norm=49.99%, eps=9.88e-03
#     Iteration s=120, norm=47.80%, eps=2.22e-02
#     Iteration s=130, norm=54.19%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=120, norm=54.19%, eps=5.78e-04
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     Iteration s=110, norm=54.19%, eps=1.00e-05
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 109 iterations
# Assimilation at t=196 completed in 109 iterations
