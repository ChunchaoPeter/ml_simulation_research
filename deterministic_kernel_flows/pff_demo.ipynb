# %%
"""
Example Usage of ParticleFlowFilter Class

This script demonstrates how to use the ParticleFlowFilter class
to perform data assimilation on the Lorenz 96 model.
"""

import tensorflow as tf
import numpy as np
from pff import ParticleFlowFilter

from utils_pff_l96_rk4 import (
    L96_RK4, generate_L96_trajectory, generate_observations,
    generate_initial_ensemble, run_ensemble_no_DA,
    generate_Hx_si, H_linear_adjoint
)

# Set random seeds for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# # 1. EXPERIMENT SETUP

# %%
# Data assimilation settings
nt = 50               # Number of integration timesteps
warm_nt = 1000         # Warm up time for Lorenz model
np_particles = 30      # Number of particles

# L96 model parameters
dim = 40               # Dimension of Lorenz 96 model
F = 8.0                # Forcing parameter
dt = 0.01              # Time resolution

# Background error covariance
Q = 2 * tf.eye(dim, dtype=tf.float32)


# Observation setup
dim_interval = 4            # Observation density
obs_input = np.arange(dim_interval-1, dim, dim_interval)  # Python uses 0-indexing
ny_obs = len(obs_input)

nx = 40                     # Full state dimension
obs_interval = 4            # Observation frequency
obs_err = 0.3               # Observation error standard deviation
R = obs_err**2 * tf.eye(ny_obs, dtype=tf.float32)

# %% [markdown]
# # 2. GENERATE TRUTH AND OBSERVATIONS

# %%
# Generate truth trajectory
Xt = generate_L96_trajectory(
        dim, warm_nt, nt, dt, F, L96_RK4
)

# Generate observations
y_obs, obs_indices, dim_indices = generate_observations(
    Xt, nt, warm_nt, obs_interval, dim_interval, R, nx
)

# Generate initial ensemble
X = generate_initial_ensemble(
    Xt, warm_nt, dim, np_particles, nt, Q
)

# Run free forecast (no DA) for comparison
XnoDA = run_ensemble_no_DA(X, nt, dt, F, L96_RK4)
# Out:
# Integrating L96 model...
#   Step 200/1050
#   Step 400/1050
#   Step 600/1050
#   Step 800/1050
#   Step 1000/1050
# Initial ensemble generated with 30 particles
# Running ensemble without DA (free run)...
# Free run complete!

# %% [markdown]
# # 3. INITIALIZE PARTICLE FLOW FILTER

# %%
alpha = 1.0 / np_particles

# PFF prior assumptions
inflation_fac = 1.25        # Inflation factor for prior covariance
r_influ = 4                 # Localization radius

# PFF iteration parameters
max_pseudo_step = 150       # Maximum number of iterations
eps_init = 5e-2             # Initial learning rate
stop_cri_percentage = 0.05  # Percentage-based stopping criterion
min_learning_rate = 1e-5    # Minimum learning rate
total_obs = nt // obs_interval  # Total number of observations

# %%
pff = ParticleFlowFilter(
    dim=dim,
    np_particles=np_particles,
    nt=nt,
    obs_interval=obs_interval,
    dim_interval=dim_interval,
    total_obs = total_obs,
    nx=nx,
    R=R,
    alpha=alpha,
    max_pseudo_step=max_pseudo_step,
    eps_init=eps_init,
    stop_cri_percentage=stop_cri_percentage,
    min_learning_rate=min_learning_rate,
    inflation_fac=inflation_fac,
    r_influ=r_influ,
    generate_Hx_si=generate_Hx_si,
    H_linear_adjoint=H_linear_adjoint
)

# %% [markdown]
# # 4.RUN DATA ASSIMILATION

# %%
DA_run = True

# %%
if DA_run:
    # Convert X to list format
    X_list = [X[:, :, i] for i in range(nt)]
    
    # Define model step function
    def model_step(X_current):
        """Wrapper for L96_RK4 model step."""
        return L96_RK4(X_current, dt, F=8)
    
    # Run PFF assimilation
    X_list_updated = pff.run(
        X_list=X_list,
        y_obs=y_obs,
        model_step=model_step,
        t_start=0,
        verbose=False
    )
    
    # Convert back to array format
    X_DA = tf.stack(X_list_updated, axis=2)
    
    print("\nData assimilation complete!")
    print(f"Output shape: {X_DA.shape}")
    
    # Save results
    # np.save('X_DA.npy', X_DA.numpy())
    
    # Get gradient history for diagnostics
    # grad_history = pff.get_gradient_history()
    # np.save('gradient_history.npy', grad_history)
# Out:
#     [Note] eps changed to 7.50e-02, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#
# Data assimilation complete!
# Output shape: (40, 30, 50)

# %%
import matplotlib.pyplot as plt

# Calculate RMSE for both DA and no-DA runs
truth = Xt[:, warm_nt:warm_nt+nt]

# Ensemble mean
X_mean_DA = np.mean(X_DA, axis=1)
X_mean_noDA = np.mean(XnoDA, axis=1)

# RMSE over time
rmse_DA = np.sqrt(np.mean((X_mean_DA - truth)**2, axis=0))
rmse_noDA = np.sqrt(np.mean((X_mean_noDA - truth)**2, axis=0))

print(f"\nRMSE Statistics:")
print(f"  DA run - Mean RMSE: {np.mean(rmse_DA):.4f}")
print(f"  No-DA run - Mean RMSE: {np.mean(rmse_noDA):.4f}")
print(f"  Improvement: {(1 - np.mean(rmse_DA)/np.mean(rmse_noDA))*100:.2f}%")

# Plot RMSE comparison
plt.figure(figsize=(12, 4))
plt.plot(rmse_noDA, label='No DA', linewidth=2)
plt.plot(rmse_DA, label='With PFF DA', linewidth=2)
plt.xlabel('Time step')
plt.ylabel('RMSE')
plt.title('Root Mean Square Error: DA vs No-DA')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Plot ensemble spread
fig, axes = plt.subplots(2, 1, figsize=(12, 8))

# No-DA run
axes[0].imshow(X_mean_noDA, aspect='auto', cmap='RdBu_r', interpolation='nearest')
axes[0].set_title('Ensemble Mean - No DA')
axes[0].set_ylabel('State dimension')

# DA run
im = axes[1].imshow(X_mean_DA, aspect='auto', cmap='RdBu_r', interpolation='nearest')
axes[1].set_title('Ensemble Mean - With PFF DA')
axes[1].set_xlabel('Time step')
axes[1].set_ylabel('State dimension')

plt.colorbar(im, ax=axes, label='State value')
plt.tight_layout()
plt.show()

# Plot sample trajectory
sample_dim = 0
plt.figure(figsize=(12, 4))
plt.plot(truth[sample_dim, :], 'k-', linewidth=2, label='Truth', alpha=0.7)
plt.plot(X_mean_noDA[sample_dim, :], 'b--', linewidth=1.5, label='No DA')
plt.plot(X_mean_DA[sample_dim, :], 'r-', linewidth=1.5, label='With PFF DA')
plt.xlabel('Time step')
plt.ylabel('State value')
plt.title(f'Sample trajectory (dimension {sample_dim})')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# RMSE Statistics:
#   DA run - Mean RMSE: 1.1242
#   No-DA run - Mean RMSE: 1.6981
#   Improvement: 33.80%
# /var/folders/fr/7vt2v5bs1f37tzqpnrrq0l880000gn/T/ipykernel_43019/1431567901.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # 5.ALTERNATIVE: MANUAL ASSIMILATION AT EACH TIME

# %%
# If you want more control, you can manually call assimilate() at each time:
if True:  # Set to True to run this example
    X_list_manual = [X[:, :, i] for i in range(nt)]
    t = 0
    
    while t < nt - 1:
        # Forecast
        X_next = L96_RK4(X_list_manual[t], dt, F)
        X_list_manual[t+1] = X_next
        
        # Check for observation
        if (t + 1) % obs_interval == 0:
            obs_time = (t + 1) // obs_interval -1
            
            # Perform assimilation
            X_list_manual[t+1], iterations = pff.assimilate(
                X_list=X_list_manual,
                y_obs=y_obs,
                t=t,
                obs_time=obs_time,
                verbose=True
            )
            
            print(f"Assimilation at t={t+1} completed in {iterations} iterations")
        
        t += 1
# Out:
#   Time t=4, Observation 1/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     Iteration s=10, norm=22.77%, eps=7.50e-02
#     [Note] eps changed to 7.50e-02, redo iteration
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=24.86%, eps=9.88e-03
#     Iteration s=20, norm=13.12%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=30, norm=13.10%, eps=9.88e-03
#     Iteration s=40, norm=10.07%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=40, norm=10.39%, eps=4.39e-03
#     Iteration s=50, norm=11.57%, eps=6.58e-03
#     Iteration s=60, norm=12.19%, eps=9.88e-03
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=60, norm=12.97%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     Iteration s=50, norm=12.97%, eps=5.07e-05
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 45 iterations
# Assimilation at t=4 completed in 45 iterations
#
#   Time t=8, Observation 2/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=10, norm=94.66%, eps=2.22e-02
#     Iteration s=20, norm=93.10%, eps=3.33e-02
#     Iteration s=30, norm=79.72%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=40, norm=72.81%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=40, norm=75.38%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=40, norm=75.71%, eps=5.78e-04
#     Iteration s=50, norm=76.81%, eps=8.67e-04
#     Iteration s=60, norm=78.54%, eps=1.95e-03
#     Iteration s=70, norm=80.36%, eps=2.93e-03
#     Iteration s=80, norm=80.11%, eps=4.39e-03
#     Iteration s=90, norm=81.24%, eps=6.58e-03
#     Iteration s=100, norm=80.91%, eps=1.48e-02
#     Iteration s=110, norm=82.11%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=110, norm=82.89%, eps=8.67e-04
#     Iteration s=120, norm=84.47%, eps=1.30e-03
#     Iteration s=130, norm=87.22%, eps=1.95e-03
#     Iteration s=140, norm=89.87%, eps=2.93e-03
#   PFF completed in 149 iterations
# Assimilation at t=8 completed in 149 iterations
#
#   Time t=12, Observation 3/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=55.09%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=20, norm=34.31%, eps=9.88e-03
#     Iteration s=30, norm=34.73%, eps=1.48e-02
#     Iteration s=40, norm=27.00%, eps=3.33e-02
#     Iteration s=50, norm=19.13%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=50, norm=20.63%, eps=6.58e-03
#     Iteration s=60, norm=21.90%, eps=9.88e-03
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=60, norm=24.27%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     Iteration s=50, norm=24.27%, eps=2.26e-05
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     Iteration s=50, norm=24.27%, eps=1.00e-05
#     Iteration s=60, norm=24.27%, eps=1.50e-05
#     Iteration s=70, norm=24.28%, eps=2.26e-05
#     Iteration s=80, norm=24.29%, eps=5.07e-05
#     Iteration s=90, norm=24.32%, eps=7.61e-05
#     Iteration s=100, norm=24.35%, eps=1.14e-04
#     Iteration s=110, norm=24.41%, eps=1.71e-04
#     Iteration s=120, norm=24.51%, eps=3.85e-04
#     Iteration s=130, norm=24.64%, eps=5.78e-04
#     Iteration s=140, norm=24.80%, eps=8.67e-04
#   PFF completed in 149 iterations
# Assimilation at t=12 completed in 149 iterations
#
#   Time t=16, Observation 4/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=51.84%, eps=1.48e-02
#     Iteration s=20, norm=37.35%, eps=3.33e-02
#     Iteration s=30, norm=26.65%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=30, norm=30.86%, eps=5.78e-04
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     Iteration s=30, norm=30.88%, eps=2.57e-04
#     Iteration s=40, norm=30.99%, eps=3.85e-04
#     Iteration s=50, norm=31.17%, eps=5.78e-04
#     Iteration s=60, norm=31.45%, eps=1.30e-03
#     Iteration s=70, norm=31.85%, eps=1.95e-03
#     Iteration s=80, norm=32.42%, eps=2.93e-03
#     Iteration s=90, norm=33.59%, eps=4.39e-03
#     Iteration s=100, norm=36.84%, eps=9.88e-03
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     Iteration s=100, norm=42.51%, eps=5.78e-04
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     Iteration s=90, norm=42.51%, eps=1.00e-05
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 89 iterations
# Assimilation at t=16 completed in 89 iterations
#
#   Time t=20, Observation 5/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 5.00e-02, redo iteration
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=10, norm=53.72%, eps=1.48e-02
#     Iteration s=20, norm=37.14%, eps=3.33e-02
#     Iteration s=30, norm=24.16%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=30, norm=24.92%, eps=1.48e-02
#     Iteration s=40, norm=19.31%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=40, norm=19.81%, eps=1.95e-03
#     Iteration s=50, norm=20.14%, eps=2.93e-03
#     Iteration s=60, norm=20.88%, eps=4.39e-03
#     Iteration s=70, norm=21.85%, eps=6.58e-03
#     Iteration s=80, norm=22.84%, eps=1.48e-02
#     Iteration s=90, norm=24.18%, eps=2.22e-02
#     Iteration s=100, norm=17.71%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=110, norm=17.74%, eps=9.88e-03
#     Iteration s=120, norm=13.90%, eps=1.48e-02
#     Iteration s=130, norm=12.26%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=130, norm=12.75%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=130, norm=12.90%, eps=1.95e-03
#     Iteration s=140, norm=13.57%, eps=2.93e-03
#   PFF completed in 149 iterations
# Assimilation at t=20 completed in 149 iterations
#
#   Time t=24, Observation 6/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=69.52%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=77.22%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=48.57%, eps=9.88e-03
#     Iteration s=20, norm=41.85%, eps=1.48e-02
#     Iteration s=30, norm=35.66%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=40, norm=27.72%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=40, norm=28.38%, eps=6.58e-03
#     Iteration s=50, norm=28.82%, eps=9.88e-03
#     Iteration s=60, norm=23.89%, eps=1.48e-02
#     Iteration s=70, norm=21.28%, eps=2.22e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=70, norm=21.91%, eps=1.95e-03
#     Iteration s=80, norm=22.41%, eps=2.93e-03
#     Iteration s=90, norm=23.25%, eps=4.39e-03
#     Iteration s=100, norm=23.79%, eps=6.58e-03
#     Iteration s=110, norm=23.08%, eps=1.48e-02
#     Iteration s=120, norm=24.61%, eps=2.22e-02
#     Iteration s=130, norm=14.69%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=140, norm=12.08%, eps=1.48e-02
#   PFF completed in 149 iterations
# Assimilation at t=24 completed in 149 iterations
#
#   Time t=28, Observation 7/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=90.40%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=10, norm=71.18%, eps=2.93e-03
#     Iteration s=20, norm=52.13%, eps=6.58e-03
#     Iteration s=30, norm=48.13%, eps=9.88e-03
#     Iteration s=40, norm=43.93%, eps=1.48e-02
#     Iteration s=50, norm=35.76%, eps=2.22e-02
#     Iteration s=60, norm=31.92%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=60, norm=33.44%, eps=9.88e-03
#     Iteration s=70, norm=26.80%, eps=1.48e-02
#     Iteration s=80, norm=22.62%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=90, norm=24.58%, eps=4.39e-03
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     Iteration s=90, norm=27.30%, eps=3.85e-04
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     Iteration s=80, norm=27.30%, eps=6.68e-06
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 80 iterations
# Assimilation at t=28 completed in 80 iterations
#
#   Time t=32, Observation 8/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=1.48e-02
#     Iteration s=10, norm=60.04%, eps=2.22e-02
#     Iteration s=20, norm=46.30%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=30, norm=33.18%, eps=2.22e-02
#     Iteration s=40, norm=28.27%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=40, norm=30.04%, eps=9.88e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=40, norm=27.00%, eps=2.93e-03
#     Iteration s=50, norm=25.39%, eps=4.39e-03
#     Iteration s=60, norm=23.98%, eps=6.58e-03
#     Iteration s=70, norm=22.07%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=80, norm=22.88%, eps=1.95e-03
#     Iteration s=90, norm=24.24%, eps=2.93e-03
#     Iteration s=100, norm=26.99%, eps=4.39e-03
#     Iteration s=110, norm=24.50%, eps=6.58e-03
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=120, norm=24.26%, eps=1.95e-03
#     Iteration s=130, norm=26.53%, eps=4.39e-03
#     Iteration s=140, norm=22.67%, eps=6.58e-03
#   PFF completed in 149 iterations
# Assimilation at t=32 completed in 149 iterations
#
#   Time t=36, Observation 9/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=0, norm=100.00%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=66.67%, eps=9.88e-03
#     Iteration s=20, norm=53.40%, eps=1.48e-02
#     Iteration s=30, norm=40.60%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     Iteration s=40, norm=28.91%, eps=4.39e-03
#     Iteration s=50, norm=27.42%, eps=9.88e-03
#     Iteration s=60, norm=25.02%, eps=1.48e-02
#     Iteration s=70, norm=22.66%, eps=2.22e-02
#     Iteration s=80, norm=20.56%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=80, norm=21.68%, eps=3.33e-02
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=80, norm=21.31%, eps=9.88e-03
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     Iteration s=80, norm=22.89%, eps=1.95e-03
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     Iteration s=80, norm=22.96%, eps=3.85e-04
#     Iteration s=90, norm=23.20%, eps=5.78e-04
#     Iteration s=100, norm=23.67%, eps=1.30e-03
#     Iteration s=110, norm=24.60%, eps=1.95e-03
#     Iteration s=120, norm=26.56%, eps=2.93e-03
#     Iteration s=130, norm=30.07%, eps=4.39e-03
#     Iteration s=140, norm=27.93%, eps=9.88e-03
#   PFF completed in 149 iterations
# Assimilation at t=36 completed in 149 iterations
#
#   Time t=40, Observation 10/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     Iteration s=10, norm=85.35%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=10, norm=72.09%, eps=2.93e-03
#     Iteration s=20, norm=43.35%, eps=6.58e-03
#     Iteration s=30, norm=40.68%, eps=9.88e-03
#     Iteration s=40, norm=39.60%, eps=1.48e-02
#     Iteration s=50, norm=28.74%, eps=2.22e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=50, norm=33.78%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     Iteration s=50, norm=33.05%, eps=1.71e-04
#     Iteration s=60, norm=31.03%, eps=2.57e-04
#     Iteration s=70, norm=27.92%, eps=5.78e-04
#     Iteration s=80, norm=25.00%, eps=8.67e-04
#     Iteration s=90, norm=23.90%, eps=1.30e-03
#     Iteration s=100, norm=23.75%, eps=1.95e-03
#     Iteration s=110, norm=23.73%, eps=4.39e-03
#     Iteration s=120, norm=23.83%, eps=6.58e-03
#     Iteration s=130, norm=23.45%, eps=9.88e-03
#     Iteration s=140, norm=23.35%, eps=1.48e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     Iteration s=140, norm=24.16%, eps=1.48e-02
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     Iteration s=130, norm=24.16%, eps=2.57e-04
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     Iteration s=130, norm=24.18%, eps=1.14e-04
#     Iteration s=140, norm=24.25%, eps=1.71e-04
#   PFF completed in 149 iterations
# Assimilation at t=40 completed in 149 iterations
#
#   Time t=44, Observation 11/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=10, norm=52.45%, eps=2.93e-03
#     Iteration s=20, norm=49.40%, eps=6.58e-03
#     Iteration s=30, norm=46.06%, eps=9.88e-03
#     Iteration s=40, norm=41.19%, eps=1.48e-02
#     Iteration s=50, norm=35.98%, eps=2.22e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     Iteration s=50, norm=41.10%, eps=1.30e-03
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     Iteration s=50, norm=40.67%, eps=7.61e-05
#     Iteration s=60, norm=39.83%, eps=1.14e-04
#     Iteration s=70, norm=38.57%, eps=1.71e-04
#     Iteration s=80, norm=36.81%, eps=2.57e-04
#     Iteration s=90, norm=34.77%, eps=5.78e-04
#     Iteration s=100, norm=33.30%, eps=8.67e-04
#     Iteration s=110, norm=32.71%, eps=1.30e-03
#     Iteration s=120, norm=32.30%, eps=1.95e-03
#     Iteration s=130, norm=31.54%, eps=4.39e-03
#     Iteration s=140, norm=30.30%, eps=6.58e-03
#   PFF completed in 149 iterations
# Assimilation at t=44 completed in 149 iterations
#
#   Time t=48, Observation 12/12
#     Iteration s=0, norm=100.00%, eps=5.00e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=10, norm=59.05%, eps=1.48e-02
#     Iteration s=20, norm=48.63%, eps=2.22e-02
#     Iteration s=30, norm=38.78%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     Iteration s=30, norm=40.51%, eps=9.88e-03
#     Iteration s=40, norm=34.12%, eps=1.48e-02
#     Iteration s=50, norm=33.77%, eps=2.22e-02
#     Iteration s=60, norm=29.10%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     Iteration s=60, norm=31.68%, eps=2.22e-02
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     Iteration s=60, norm=27.95%, eps=6.58e-03
#     Iteration s=70, norm=27.44%, eps=9.88e-03
#     Iteration s=80, norm=28.01%, eps=1.48e-02
#     Iteration s=90, norm=29.85%, eps=3.33e-02
#     [Note] eps changed to 3.33e-02, redo iteration
#     [Note] eps changed to 2.22e-02, redo iteration
#     [Note] eps changed to 1.48e-02, redo iteration
#     [Note] eps changed to 9.88e-03, redo iteration
#     [Note] eps changed to 6.58e-03, redo iteration
#     [Note] eps changed to 4.39e-03, redo iteration
#     [Note] eps changed to 2.93e-03, redo iteration
#     Iteration s=90, norm=31.43%, eps=2.93e-03
#     [Note] eps changed to 1.95e-03, redo iteration
#     [Note] eps changed to 1.30e-03, redo iteration
#     [Note] eps changed to 8.67e-04, redo iteration
#     [Note] eps changed to 5.78e-04, redo iteration
#     [Note] eps changed to 3.85e-04, redo iteration
#     [Note] eps changed to 2.57e-04, redo iteration
#     [Note] eps changed to 1.71e-04, redo iteration
#     [Note] eps changed to 1.14e-04, redo iteration
#     [Note] eps changed to 7.61e-05, redo iteration
#     [Note] eps changed to 5.07e-05, redo iteration
#     Iteration s=80, norm=31.43%, eps=5.07e-05
#     [Note] eps changed to 3.38e-05, redo iteration
#     [Note] eps changed to 2.26e-05, redo iteration
#     [Note] eps changed to 1.50e-05, redo iteration
#     [Note] eps changed to 1.00e-05, redo iteration
#     [Note] eps changed to 6.68e-06, redo iteration
#     [Note] Learning rate too small, stopping iteration
#   PFF completed in 75 iterations
# Assimilation at t=48 completed in 75 iterations
